# %%
import Neural_Network as nn

# %% [markdown]
# **Set the path to Dataset:**

# %%
path='Data/241212_Dataset_Leopard24_IMU.csv'

# %% [markdown]
# **Set preprocessing parameters:**
# Height filtering can lead to zero columns. Therefore variance thresholding comes after height filtering. If you want to delete the unnecessary columns keep variance_thresholding = True.
#
# See the data structure below for understanding:
# ![image.png](attachment:image.png)

# %%
add_propsensor_features=False

height_filtering=False
height_lower=500
height_upper=1000

create_trial_identifier=False

variance_thresholding=True
variance_threshold=0.15

testdata_size=0.2

target='ElbowAngle' # WristAngle, ShoulderAngleZ (flexion/extension), ShoulderAngleX (abduction/adduction)

scaler_X='StandardScaler' # StandardScaler, MinMaxScaler, RobustScaler, QuantileTransformer, PowerTransformer

n_scross_val=5 # min 3

# %% [markdown]
# **Run the Neural Network Training with all give parameters:**

# %%
nn.main(path, height_filtering, height_lower, height_upper, create_trial_identifier, variance_thresholding, variance_threshold,
        testdata_size, target, scaler_X, add_propsensor_features, n_scross_val)
# %debug
# Out:
# ===Fold 1===
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nn.main(path, height_filtering, height_lower, height_upper, create_trial_identifier, variance_thresholding, variance_threshold,
#       2         testdata_size, target, scaler_X, add_propsensor_features, n_scross_val)
#       3 get_ipython().run_line_magic('debug', '')
#
# File ~/Documents/Microsoft Visual Studio Code Projects/Masterarbeit/Neural_Network.py:119, in main(fileName, height_filtering, height_lower, height_upper, create_trial_identifier, var_thresholding, var_threshold, testdata_size, target, scalewith, add_prop_features, n_cross_val)
#     117 config = wandb.config
#     118 X_train_val, X_val = X_train[train_index], X_train[val_index]
# --> 119 y_train_val, y_val = y_train[train_index], y_train[val_index]
# ...
